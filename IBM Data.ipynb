# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import re

# %%
intake = pd.read_csv('intake_data_Executive Presence Studio - Feb25.csv')
post = pd.read_csv('post_data_Executive Presence Studio - Feb25.csv')
takes = pd.read_csv('takes_of_users_in_Executive Presence Studio - Feb25.csv')
users = pd.read_csv('users_in_Executive Presence Studio - Feb25.csv')
watch = pd.read_csv('watch_data_of_users_in_Executive Presence Studio - Feb25.csv')

# %%
intake.head()
# Out:
#   Connect to my audience when recording Elicit a variety of emotions  \
# 0                          2- Somewhat.                 2- Somewhat.
# 1                          2- Somewhat.                 2- Somewhat.
# 2                      1 - Not so much.                 2- Somewhat.
# 3                          2- Somewhat.          3 - Pretty familiar
# 4                          2- Somewhat.                 2- Somewhat.
#
#   Empowers me personally Empowers me professionally English native language  \
# 0       1 - Not so much.           1 - Not so much.                     Yes
# 1           2- Somewhat.               2- Somewhat.                      No
# 2           2- Somewhat.               2- Somewhat.                      No
# 3           2- Somewhat.               2- Somewhat.                      No
# 4           2- Somewhat.               2- Somewhat.                      No
#
#   Familiar with power of presence First Name  Gender  \
# 0             3 - Pretty familiar       Aman    Male
# 1             3 - Pretty familiar     Angela  Female
# 2                    2- Somewhat.      Nitin    Male
# 3                    2- Somewhat.      Adnan    Male
# 4             3 - Pretty familiar    Facundo    Male
#
#   Headspace to record my message Last Name  ...  Preferred Name  \
# 0            3 - Pretty familiar    Bhatia  ...            Aman
# 1                4 - Absolutely!   Adamyan  ...          Angela
# 2                   2- Somewhat.     Goyal  ...           Nitin
# 3                   2- Somewhat.  Seddighi  ...           Adnan
# 4                   2- Somewhat.   Rinaldi  ...  Facu / Facundo
#
#                               Questions for BetterOn  \
# 0  I would like to enhance my executive presence ...
# 1  to be confident in my interactions with the cl...
# 2                                                NaN
# 3           i want to establish trust with audience
# 4  Being comfortable discussing any topic on vide...
#
#                         Race ethnicity Shift to on video me  \
# 0  Asian [American] / Pacific Islander         2- Somewhat.
# 1                     White, Caucasian  3 - Pretty familiar
# 2                  I prefer not to say     1 - Not so much.
# 3                       Middle Eastern         2- Somewhat.
# 4        Hispanic / Latino(a) / Latinx     1 - Not so much.
#
#   Technical aspects of my presence    Warm up exercises         Creation Date  \
# 0              3 - Pretty familiar         2- Somewhat.  Feb 10, 2025 3:06 pm
# 1                     2- Somewhat.  3 - Pretty familiar  Feb 10, 2025 5:10 pm
# 2                     2- Somewhat.  3 - Pretty familiar  Feb 10, 2025 7:06 pm
# 3              3 - Pretty familiar         2- Somewhat.  Feb 11, 2025 9:16 am
# 4                     2- Somewhat.         2- Somewhat.  Feb 11, 2025 3:24 pm
#
#                           unique id                           Creator  \
# 0  1739217972014x913705819594031100  1739217555713x916998178763752400
# 1  1739225438077x304643086495514600  1739220021220x573922384520065600
# 2  1739232413883x501828949741404160  1739215211624x423248971783300540
# 3  1739283410354x422647650886352900  1739221010204x312756285187473500
# 4  1739305454984x839460178804342800  1739220038097x395822659655955800
#
#        Created By - email
# 0     aman.bhatia@ibm.com
# 1  angela.adamyan@ibm.com
# 2  nitin.goyal@in.ibm.com
# 3           adnan@ibm.com
# 4     frinaldi@cr.ibm.com
#
# [5 rows x 23 columns]
